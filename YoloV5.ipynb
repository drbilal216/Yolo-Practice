# %% [markdown]
# <a href="https://colab.research.google.com/github/drbilal216/Yolo-Practice/blob/main/YoloV5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SUBSCRIBE to the [channel](https://www.youtube.com/user/19daredevill?sub_confirmation=1) to learn cool things**

# %%
# https://www.youtube.com/watch?v=K-MKtnlhS6A

# %% [markdown]
# **Step 1 : Clone yolov5 repository**

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 3853, done.
# remote: Total 3853 (delta 0), reused 0 (delta 0), pack-reused 3853
# Receiving objects: 100% (3853/3853), 7.15 MiB | 36.05 MiB/s, done.
# Resolving deltas: 100% (2594/2594), done.

# %% [markdown]
# **Step 2: Change Directory to yolov5**

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %% [markdown]
# **Step 3: Install Dependencies**

# %%
# !pip install -U -r requirements.txt
# Out:
# Requirement already up-to-date: Cython in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (0.29.21)
# ...
#      |████████████████████████████████| 11.6MB 22.5MB/s
# Requirement already up-to-date: numpy>=1.18.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (1.19.4)
# ...
#      |████████████████████████████████| 50.4MB 55kB/s
# ...
#      |████████████████████████████████| 2.2MB 41.2MB/s
# ...
#      |████████████████████████████████| 276kB 57.0MB/s
# ...
#      |████████████████████████████████| 25.9MB 125kB/s
# Requirement already up-to-date: tensorboard>=2.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 11)) (2.4.0)
# ...
#      |████████████████████████████████| 776.8MB 24kB/s
# ...
#      |████████████████████████████████| 12.8MB 54.6MB/s
# ...
#      |████████████████████████████████| 71kB 10.9MB/s
# ...
#      |████████████████████████████████| 286kB 62.8MB/s
# ...

# %% [markdown]
# ##### Click on restart runtime tab above then run from below tabs

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %% [markdown]
# **Step 4: Run Object Detection on Images. Provide image path. Upload image in the data/images/ folder**

# %%
# !python detect.py --source ./data/images/zidane.jpg --weights yolov5s.pt --conf 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='./data/images/zidane.jpg', update=False, view_img=False, weights=['yolov5s.pt'])
# /usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 10010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# Using torch 1.7.1 CPU
#
# ...
# 100% 14.5M/14.5M [00:00<00:00, 113MB/s]
#
# Fusing layers...
# Model Summary: 232 layers, 7459581 parameters, 0 gradients, 17.5 GFLOPS
# ...

# %% [markdown]
# **Step 5: Display image in colab**

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

#image = cv2.imread("inference/output/zidane.jpg")
image = cv2.imread("runs/detect/exp/zidane.jpg")
height, width = image.shape[:2]
resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# **Object Detection on Videos. Create a folder under data/ called "videos", under which you can upload the video file and then provide the file path below**

# %%
# !python detect.py --source data/videos/Fmarket.mp4 --weights yolov5s.pt --conf 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/videos/Fmarket.mp4', update=False, view_img=False, weights=['yolov5s.pt'])
# /usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 10010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# Using torch 1.7.1 CPU
#
# Fusing layers...
# Model Summary: 232 layers, 7459581 parameters, 0 gradients, 17.5 GFLOPS
# ...

# %%
# Downloading Video
from google.colab import files
files.download('/content/yolov5/runs/detect/exp2/Fmarket.mp4')

# %%
#################### End #################

# %% [markdown]
# ### Moving folder in google drive so that don,t have to do these steps again

# %%
# mounting Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# im currently is in this folder
import os
os.listdir(".")
# Out:
# ['requirements.txt',
#  'data',
#  '.gitattributes',
#  'hubconf.py',
#  'train.py',
#  'models',
#  'weights',
#  'README.md',
#  'runs',
#  'LICENSE',
#  '.dockerignore',
#  'Dockerfile',
#  '.gitignore',
#  '.git',
#  'tutorial.ipynb',
#  'detect.py',
#  '.github',
#  'utils',
#  'test.py',
#  'yolov5s.pt']

# %%
# going out of darknet folder to content folder
# %cd .. 
# Checking folders available in content folder
os.listdir(".")
# Out:
# /content
# ['.config', 'yolov5', 'drive', 'sample_data']

# %%
# making a directory to copy files to

# !mkdir "/content/drive/My Drive/ML and AI/ComputerVision"

# %%
# Creating yolov5 folder zip in root directory

import shutil
output_filename = "yolov5"
dir_name = "yolov5"
shutil.make_archive(output_filename, 'zip', dir_name)
# Out:
# '/content/yolov5.zip'

# %%
# now moving this zip file to directory created earlier
# trying above copying codes again

copyFrom = "/content/yolov5.zip"
copyTo = "/content/drive/My Drive/ML and AI/ComputerVision"

import shutil
shutil.copy(copyFrom, copyTo)
# Out:
# '/content/drive/My Drive/ML and AI/ComputerVision/yolov5.zip'

# %%
########## Done #############

# %% [markdown]
# ###  From now on We will always code from below

# %%
# mounting Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# making a directory to copy files to

# !mkdir "/content/yolov5"

# %%
# Copying zip file from drive

copyFrom = "/content/drive/My Drive/ML and AI/ComputerVision/yolov5.zip"
copyTo = "/content/yolov5"

import shutil
shutil.copy(copyFrom, copyTo)
# Out:
# '/content/yolov5/yolov5.zip'

# %%
# changing directory

#% cd drive/My Drive/ML and AI/darknet
#% cd content/yolov5
# %cd yolov5/
# Out:
# /content/yolov5

# %%
# unziping it
# !unzip yolov5.zip #-d my_data
# Out:
# Archive:  yolov5.zip
#    creating: .git/
#    creating: .github/
#    creating: data/
#    creating: models/
#    creating: runs/
#    creating: utils/
#    creating: weights/
#   inflating: requirements.txt
#   inflating: .gitattributes
#   inflating: hubconf.py
#   inflating: train.py
#   inflating: README.md
#   inflating: LICENSE
#   inflating: .dockerignore
#   inflating: Dockerfile
#   inflating: .gitignore
#   inflating: tutorial.ipynb
#   inflating: detect.py
#   inflating: test.py
#   inflating: yolov5s.pt
#    creating: data/.ipynb_checkpoints/
#    creating: data/images/
#    creating: data/scripts/
#    creating: data/videos/
#   inflating: data/hyp.scratch.yaml
#   inflating: data/coco.yaml
#   inflating: data/hyp.finetune.yaml
#   inflating: data/coco128.yaml
#   inflating: data/voc.yaml
#   inflating: data/scripts/get_coco.sh
#   inflating: data/scripts/get_voc.sh
#    creating: data/images/.ipynb_checkpoints/
#   inflating: data/images/zidane.jpg
# ...

# %%
# Applying on Picture
# !python detect.py --source ./data/images/zidane.jpg --weights yolov5s.pt --conf 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='./data/images/FMarketP.jpeg', update=False, view_img=False, weights=['yolov5s.pt'])
# /usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 10010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# Using torch 1.7.1 CPU
#
# Fusing layers...
# Model Summary: 232 layers, 7459581 parameters, 0 gradients, 17.5 GFLOPS
# ...

# %%
# Viewing Picture

import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread("runs/detect/exp/zidane.jpg")
height, width = image.shape[:2]
resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Applying on Video
# !python detect.py --source data/videos/Fmarket.mp4 --weights yolov5s.pt --conf 0.4

# %%
# Downloading Video
from google.colab import files
files.download('/content/yolov5/runs/detect/exp2/Fmarket.mp4')

# %%
######### Ready again ###############

# %%
# Applying on Picture
# !python detect.py --source ./data/images/bus.jpg --weights yolov5s.pt --conf 0.4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='./data/images/bus.jpg', update=False, view_img=False, weights=['yolov5s.pt'])
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079.75MB)
#
#
# Fusing layers...
# Model Summary: 232 layers, 7459581 parameters, 0 gradients
# image 1/1 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 buss, 1 skateboards, Done. (0.015s)
# Results saved to runs/detect/exp4
# Done. (0.155s)

# %%
# Viewing Picture

import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread("runs/detect/exp4/bus.jpg")
height, width = image.shape[:2]
resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()
